# %% [markdown]
# # Text Preprocessing using NLTK
#
# Tokenization, stopword removal, stemming, lemmatization and a simple bag-of-words representation.

# %%
# !pip -q install nltk
import nltk
nltk.download("punkt")
nltk.download("punkt_tab")
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download("omw-1.4")

import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

text = "Machine learning models learn useful patterns from data. The models can be trained and evaluated."

tokens = word_tokenize(text.lower())
print(tokens)

# %% [markdown]
# ## 1. Clean and remove stopwords

# %%
stop_words = set(stopwords.words("english"))
clean_tokens = [
    t for t in tokens
    if t.isalpha() and t not in stop_words
]
print(clean_tokens)

# %% [markdown]
# ## 2. Stemming and lemmatization

# %%
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

stems = [stemmer.stem(t) for t in clean_tokens]
lemmas = [lemmatizer.lemmatize(t) for t in clean_tokens]

print("Stems:", stems)
print("Lemmas:", lemmas)

# %% [markdown]
# ## 3. Bag of Words

# %%
from sklearn.feature_extraction.text import CountVectorizer

documents = [
    "machine learning learns patterns from data",
    "machine learning models are trained on data",
    "text models can learn useful patterns"
]

vectorizer = CountVectorizer(stop_words="english")
X = vectorizer.fit_transform(documents)

bow = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())
bow

# %% [markdown]
# ### Connection to class
# Text preprocessing converts unstructured text into a cleaner representation. A Bag-of-Words/DTM records term counts. TF-IDF additionally downweights terms that occur in many documents and is commonly used as an input to classical ML models.
